# %% [markdown]
# <a href="https://colab.research.google.com/github/mahalrupi/EIP-4.0/blob/master/Week5/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator


from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten,GlobalAveragePooling2D
from keras.optimizers import Adam,RMSprop
from keras.callbacks import ModelCheckpoint, LearningRateScheduler

from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation = augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        if self.augmentation is not None:
            image = self.augmentation.flow(image, shuffle=False).next()
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15,random_state=30)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 10297  resized/10299.jpg              1  ...                        0              0
# 8668    resized/8669.jpg              1  ...                        1              0
# 1412    resized/1413.jpg              1  ...                        1              0
# 9059    resized/9060.jpg              0  ...                        1              0
# 9474    resized/9475.jpg              0  ...                        1              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32, augmentation=ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip=True  ))
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
data_augmentation = True
subtract_pixel_mean = True
n = 5

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)
    Input
    inputs = Input(shape=input_shape)
  
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    y = GlobalAveragePooling2D(data_format='channels_last')(x)
    outputs = Dense(512,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    mode = Model(inputs=inputs, outputs=outputs)
    return mode

# %%
backbone = resnet_v1((224,224,3), depth=depth)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.

# %%
backbone.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 224, 224, 16) 64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 224, 224, 16) 0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 224, 224, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 224, 224, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 224, 224, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 224, 224, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 224, 224, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 224, 224, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 224, 224, 16) 0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 224, 224, 16) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 224, 224, 16) 2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 224, 224, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 224, 224, 16) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 224, 224, 16) 2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 224, 224, 16) 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 224, 224, 16) 0           activation_5[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 224, 224, 16) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 224, 224, 16) 2320        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 224, 224, 16) 64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 224, 224, 16) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 224, 224, 16) 2320        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 224, 224, 16) 64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 224, 224, 16) 0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 224, 224, 16) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 224, 224, 16) 2320        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 224, 224, 16) 64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 224, 224, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 224, 224, 16) 2320        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 224, 224, 16) 64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 224, 224, 16) 0           activation_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 224, 224, 16) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 112, 112, 32) 4640        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 112, 112, 32) 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 112, 112, 32) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 112, 112, 32) 9248        activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 112, 112, 32) 544         activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 112, 112, 32) 128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 112, 112, 32) 0           conv2d_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 112, 112, 32) 0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 112, 112, 32) 9248        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 112, 112, 32) 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 112, 112, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 112, 112, 32) 9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 112, 112, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 112, 112, 32) 0           activation_13[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 112, 112, 32) 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 112, 112, 32) 9248        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 112, 112, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 112, 112, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 112, 112, 32) 9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 112, 112, 32) 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 112, 112, 32) 0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 112, 112, 32) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 112, 112, 32) 9248        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 112, 112, 32) 128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 112, 112, 32) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 112, 112, 32) 9248        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 112, 112, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 112, 112, 32) 0           activation_17[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 112, 112, 32) 0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 112, 112, 32) 9248        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 112, 112, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 112, 112, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 112, 112, 32) 9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 112, 112, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 112, 112, 32) 0           activation_19[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 112, 112, 32) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 64)   18496       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 56, 56, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 56, 56, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 64)   36928       activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 56, 56, 64)   2112        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 56, 56, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 56, 56, 64)   0           conv2d_25[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 56, 56, 64)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 56, 56, 64)   36928       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 56, 56, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 56, 56, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 56, 56, 64)   36928       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 56, 56, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 56, 56, 64)   0           activation_23[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 56, 56, 64)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 56, 56, 64)   36928       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 56, 56, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 56, 56, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 56, 56, 64)   36928       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 56, 56, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 56, 56, 64)   0           activation_25[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 56, 56, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 64)   36928       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 56, 56, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 56, 56, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 64)   36928       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 56, 56, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 56, 56, 64)   0           activation_27[0][0]
#                                                                  batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 56, 56, 64)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 56, 56, 64)   36928       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 56, 56, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 56, 56, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 56, 56, 64)   36928       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 56, 56, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 56, 56, 64)   0           activation_29[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 56, 56, 64)   0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           activation_31[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          33280       global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 502,848
# Trainable params: 500,576
# Non-trainable params: 2,272
# __________________________________________________________________________________________________

# %%
neck = backbone.output
#neck = Flatten(name="flatten")(neck)
#neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
# freeze backbone
#for layer in backbone.layers:
#	layer.trainable = False

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "categorical_crossentropy",
 	"age_output": "categorical_crossentropy",
 	"weight_output": "categorical_crossentropy",

 }
#loss_weights = {"gender_output": 1.0, "image_quality_output": 1.0, "age_output": 0.5}
opt = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(
    optimizer=opt,
    loss="categorical_crossentropy", 
    #loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
from keras.callbacks import Callback
from keras import backend as K
import numpy as np


class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency.
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    The amplitude of the cycle can be scaled on a per-iteration or
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each
        cycle iteration.
    For more detail, please see paper.
    # Example for CIFAR-10 w/ batch size 100:
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    # References
      - [Cyclical Learning Rates for Training Neural Networks](
      https://arxiv.org/abs/1506.01186)
    """

    def __init__(
            self,
            base_lr=0.001,
            max_lr=0.006,
            step_size=2000.,
            mode='triangular',
            gamma=1.,
            scale_fn=None,
            scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        if mode not in ['triangular', 'triangular2',
                        'exp_range']:
            raise KeyError("mode must be one of 'triangular', "
                           "'triangular2', or 'exp_range'")
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn is None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1 / (2.**(x - 1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma ** x
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr is not None:
            self.base_lr = new_base_lr
        if new_max_lr is not None:
            self.max_lr = new_max_lr
        if new_step_size is not None:
            self.step_size = new_step_size
        self.clr_iterations = 0.

    def clr(self):
        cycle = np.floor(1 + self.clr_iterations / (2 * self.step_size))
        x = np.abs(self.clr_iterations / self.step_size - 2 * cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr - self.base_lr) * \
                np.maximum(0, (1 - x)) * self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr - self.base_lr) * \
                np.maximum(0, (1 - x)) * self.scale_fn(self.clr_iterations)

    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())

    def on_batch_end(self, epoch, logs=None):

        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1
        K.set_value(self.model.optimizer.lr, self.clr())

        self.history.setdefault(
            'lr', []).append(
            K.get_value(
                self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)
MIN_LR = 1e-4
MAX_LR = 3e-2

STEP_SIZE = 8
CLR_METHOD = "triangular"
NUM_EPOCHS = 96

clr = CyclicLR(
	mode=CLR_METHOD,
	base_lr=MIN_LR,
	max_lr=MAX_LR,
	step_size= STEP_SIZE * (train_df.shape[0] // 32))
  

def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 45:
        lr *= 0.5e-3
    elif epoch > 40:
        lr *= 1e-3
    elif epoch > 35:
        lr *= 1e-2
    elif epoch > 25:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

model_name = 'cifar10_%s_model.{epoch:03d}.h5'
save_dir = F"/content/gdrive/My Drive/models3"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, clr,lr_reducer]

# %%
import math
import os
import numpy as np
import warnings
from keras.callbacks import LambdaCallback
from keras.callbacks import Callback
from keras import backend as K

import numpy as np
import scipy.ndimage.filters as filters
import scipy.ndimage.morphology as morphology
import pandas as pd


import matplotlib.pyplot as plt
def detect_local_minima(arr):
    # https://stackoverflow.com/questions/4624970/finding-local-maxima-minima-with-numpy-in-a-1d-numpy-array
    # https://stackoverflow.com/questions/3986345/how-to-find-the-local-minima-of-a-smooth-multidimensional-array-in-numpy-efficien
    # https://stackoverflow.com/questions/3684484/peak-detection-in-a-2d-array/3689710#3689710
    """
    Takes an array and detects the troughs using the local maximum filter.
    Returns a boolean mask of the troughs (i.e. 1 when
    the pixel's value is the neighborhood maximum, 0 otherwise)
    """
    # define an connected neighborhood
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.morphology.html#generate_binary_structure
    neighborhood = morphology.generate_binary_structure(len(arr.shape), 2)
    # apply the local minimum filter; all locations of minimum value
    # in their neighborhood are set to 1
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.filters.html#minimum_filter
    local_min = (filters.minimum_filter(arr, footprint=neighborhood) == arr)
    # local_min is a mask that contains the peaks we are
    # looking for, but also the background.
    # In order to isolate the peaks we must remove the background from the mask.
    #
    # we create the mask of the background
    background = (arr == 0)
    #
    # a little technicality: we must erode the background in order to
    # successfully subtract it from local_min, otherwise a line will
    # appear along the background border (artifact of the local minimum filter)
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.morphology.html#binary_erosion
    eroded_background = morphology.binary_erosion(
        background, structure=neighborhood, border_value=1)
    #
    # we obtain the final mask, containing only peaks,
    # by removing the background from the local_min mask
    detected_minima = local_min ^ eroded_background
    return np.where(detected_minima)


def moving_average_fast(x, w):
    # https://stackoverflow.com/questions/14313510/how-to-calculate-moving-average-using-numpy
    return np.convolve(np.array(x), np.ones(w), 'same') / w


def moving_average(x, w):
    df = pd.DataFrame({"x": x})
    return df.rolling(w, win_type=None, min_periods=1, center=True).mean()['x'].values

def get_derivatives(vals, sma=10):
    assert sma >= 1
    derivatives = [0] * sma
    losses = moving_average(vals, 5)
    for i in range(sma, len(vals)):
        derivatives.append((losses[i] - losses[i - sma]) / sma)
    return derivatives
class LRFinder:
    """
    Plots the change of the loss function of a Keras model when the learning rate is exponentially increasing.
    See for details:
    https://towardsdatascience.com/estimating-optimal-learning-rate-for-a-deep-neural-network-ce32f2556ce0
    """

    def __init__(self, model, num_validation_batches=10):
        self.model = model
        self.losses = []
        self.acc = []
        self.lrs = []
        self.best_loss = 1e9
        self.best_acc = 0
        self.one_minus_acc = []
        self.one_minus_acc_best = []
        self.num_validation_batches = num_validation_batches
        self.validation_set = None
        self.validation_generator = None

    def on_batch_end(self, batch, logs):
        # Log the learning rate
        lr = K.get_value(self.model.optimizer.lr)
        self.lrs.append(lr)

        # Log the loss
        loss = logs['loss']
        acc = logs['gender_output_acc']

        self.losses.append(loss)
        self.acc.append(acc)
        self.one_minus_acc.append(1 - acc)

        # Check whether the loss got too large or NaN
        if batch > 16 and (math.isnan(loss) or loss > self.best_loss * 10):
            self.model.stop_training = True
            print("Stop Training at %s, loss = %.3f" % (batch, loss))
            return

        if loss < self.best_loss:
            self.best_loss = loss
        if acc > self.best_acc:
            self.best_acc = acc

        # Increase the learning rate for the next batch
        lr *= self.lr_mult
        K.set_value(self.model.optimizer.lr, lr)

    def find(self, x_train, y_train, start_lr, end_lr,
             x_test=None, y_test=None,
             batch_size=64, epochs=1):
        num_batches = epochs * x_train.shape[0] / batch_size
        self.lr_mult = (float(end_lr) / float(start_lr)) ** (float(1) / float(num_batches))

        # Save weights into a file
        self.model.save_weights('tmp.h5')

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch, logs: self.on_batch_end(batch, logs))
        self.validation_set = (x_test, y_test) if x_test is not None and y_test is not None else None
        self.batch_size = batch_size

        self.model.fit(x_train, y_train,
                       batch_size=batch_size, epochs=epochs,
                       verbose=0,
                       callbacks=[callback])

        # Restore the weights to the state before model fitting
        self.model.load_weights('tmp.h5')

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def find_generator(self, generator, start_lr, end_lr,
                       test_generator=None,
                       epochs=1, steps_per_epoch=None, **kw_fit):
        if steps_per_epoch is None:
            try:
                steps_per_epoch = len(generator)
            except (ValueError, NotImplementedError) as e:
                raise e('`steps_per_epoch=None` is only valid for a'
                        ' generator based on the '
                        '`keras.utils.Sequence`'
                        ' class. Please specify `steps_per_epoch` '
                        'or use the `keras.utils.Sequence` class.')
        self.lr_mult = (float(end_lr) / float(start_lr)) ** (float(1) / float(steps_per_epoch * epochs))

        # Save weights into a file
        self.model.save_weights('tmp.h5')

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch,
                                                      logs: self.on_batch_end(batch, logs))

        self.validation_generator = test_generator

        self.model.fit_generator(generator=generator,
                                 epochs=epochs,
                                 steps_per_epoch=steps_per_epoch,
                                 callbacks=[callback],
                                 verbose=0,
                                 **kw_fit)

        # Restore the weights to the state before model fitting
        self.model.load_weights('tmp.h5')

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def plot_loss(self, n_skip_beginning=5, n_skip_end=5, sma=20):
        self.__plot__(n_skip_beginning,n_skip_end,sma,use_acc=False)

    def plot_one_minus_acc(self, n_skip_beginning=5, n_skip_end=5, sma=20):
        self.__plot__(n_skip_beginning,n_skip_end,sma,use_acc=True)

    def __plot__(self, n_skip_beginning=5, n_skip_end=5, sma=10, use_acc=False):

        fig = plt.figure(figsize=(12, 6))
        ax = fig.add_subplot(111)
        y_label = "1 - Acc" if use_acc else "loss"
        plt.ylabel(y_label)
        plt.xlabel("learning rate (log scale)")

        losses = self.losses if not use_acc else self.one_minus_acc
        losses = moving_average(losses, sma)

        losses = losses[n_skip_beginning:-n_skip_end]

        plt.plot(self.lrs[n_skip_beginning:-n_skip_end], losses)
        plt.xscale('log')
        best_lrs = self.get_best_lrs(sma,use_acc=use_acc)
        lrs = [x for x, _ in best_lrs]
        positions = [x for _, x in best_lrs]
        # https://matplotlib.org/users/annotations_intro.html
        # for lr, pos in [best_lrs[-1]]:
        #     ax.annotate('LR = %.3f, %s = %.2f' % (lr, y_label, losses[pos]), xy=(lr, losses[pos]),
        #                 xytext=(lr + 0.2, losses[pos] + 0.1),
        #                 arrowprops=dict(facecolor='black', shrink=0.03, width=1, frac=0.05),
        #                 )

        title = "LR vs 1 - Acc Graph" if use_acc else "LR vs Loss Graph"
        # title = title + "\n" + "Best Candidate LR = %s" % lrs
        plt.title(title)
        plt.show()

    def __get_best_lr_method1__(self, sma=20, n_skip_beginning=10, n_skip_end=5, use_acc=False):
        losses = self.losses if not use_acc else self.one_minus_acc
        derivatives = get_derivatives(losses, sma)
        losses = np.array(losses[n_skip_beginning:-n_skip_end])
        derivatives = derivatives[n_skip_beginning:-n_skip_end]
        lrs = self.lrs[n_skip_beginning:-n_skip_end]

        best_loss = (1 - self.best_acc) if use_acc else self.best_loss
        acceptable_idxs = np.where(losses <= best_loss * 1.75)[0]

        derivatives = derivatives[acceptable_idxs[0]:acceptable_idxs[-1]]

        best_idxs = np.argpartition(derivatives, -5)[-5:]
        best_idxs = best_idxs - sma + acceptable_idxs[0]
        acceptable_loss_or_not = losses[best_idxs] <= best_loss * 1.5
        best_idxs = best_idxs[acceptable_loss_or_not]

        acceptable_loss_or_not = losses[best_idxs + sma] > (losses[best_idxs] * 1.0)
        best_idxs = best_idxs[acceptable_loss_or_not]

        candidates = list(np.array(lrs)[best_idxs])
        return sorted(candidates), best_idxs

    def get_best_lrs(self, sma=20, n_skip_beginning=10, n_skip_end=5, use_acc=False):
        c1, i1 = self.__get_best_lr_method1__(sma, n_skip_beginning, n_skip_end, use_acc)
        candidates = list(zip(c1, i1))
        candidates = sorted(candidates, key=lambda pair: pair[0])
        final_candidates = [candidates[0]]
        for v, i in candidates:
            if (v - final_candidates[-1][0]) / final_candidates[-1][0] > 0.2:
                final_candidates.append((v, i))
        final_candidates = list(map(lambda pair: (float("%.3f" % pair[0]), pair[1]), final_candidates))
        return final_candidates

# %%
lrf = LRFinder(model)
lrf.find_generator(train_gen, 0.00000001, 2.0,valid_gen, epochs=1, steps_per_epoch=None,)
lrf.plot_loss()

# %%
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=96,
    steps_per_epoch=train_df.shape[0] // 32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/96
# 359/360 [============================>.] - ETA: 0s - loss: 9.0315 - gender_output_loss: 0.6025 - image_quality_output_loss: 1.1534 - age_output_loss: 1.4582 - weight_output_loss: 1.4340 - bag_output_loss: 0.9693 - footwear_output_loss: 0.9932 - pose_output_loss: 1.2443 - emotion_output_loss: 0.9942 - gender_output_acc: 0.6724 - image_quality_output_acc: 0.4648 - age_output_acc: 0.3887 - weight_output_acc: 0.4813 - bag_output_acc: 0.5234 - footwear_output_acc: 0.5526 - pose_output_acc: 0.4439 - emotion_output_acc: 0.7120Epoch 1/96
# 360/360 [==============================] - 139s 386ms/step - loss: 9.0285 - gender_output_loss: 0.6024 - image_quality_output_loss: 1.1525 - age_output_loss: 1.4580 - weight_output_loss: 1.4327 - bag_output_loss: 0.9697 - footwear_output_loss: 0.9928 - pose_output_loss: 1.2432 - emotion_output_loss: 0.9947 - gender_output_acc: 0.6723 - image_quality_output_acc: 0.4652 - age_output_acc: 0.3889 - weight_output_acc: 0.4818 - bag_output_acc: 0.5234 - footwear_output_acc: 0.5528 - pose_output_acc: 0.4444 - emotion_output_acc: 0.7116 - val_loss: 8.4480 - val_gender_output_loss: 0.6126 - val_image_quality_output_loss: 0.9752 - val_age_output_loss: 1.4094 - val_weight_output_loss: 1.0192 - val_bag_output_loss: 0.9044 - val_footwear_output_loss: 1.5122 - val_pose_output_loss: 0.9207 - val_emotion_output_loss: 0.9120 - val_gender_output_acc: 0.6483 - val_image_quality_output_acc: 0.5432 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5729 - val_footwear_output_acc: 0.3705 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00001: val_loss improved from inf to 8.44797, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.001.h5
# Epoch 2/96
# 360/360 [==============================] - 135s 376ms/step - loss: 7.5968 - gender_output_loss: 0.5443 - image_quality_output_loss: 0.9069 - age_output_loss: 1.4136 - weight_output_loss: 0.9708 - bag_output_loss: 0.8809 - footwear_output_loss: 0.8792 - pose_output_loss: 0.9207 - emotion_output_loss: 0.8986 - gender_output_acc: 0.7217 - image_quality_output_acc: 0.5635 - age_output_acc: 0.3982 - weight_output_acc: 0.6399 - bag_output_acc: 0.5893 - footwear_output_acc: 0.6001 - pose_output_acc: 0.6170 - emotion_output_acc: 0.7113 - val_loss: 8.1374 - val_gender_output_loss: 0.8152 - val_image_quality_output_loss: 0.9453 - val_age_output_loss: 1.4365 - val_weight_output_loss: 1.0328 - val_bag_output_loss: 0.9233 - val_footwear_output_loss: 0.9819 - val_pose_output_loss: 0.9092 - val_emotion_output_loss: 0.9119 - val_gender_output_acc: 0.4603 - val_image_quality_output_acc: 0.5605 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.4990 - val_footwear_output_acc: 0.5476 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00002: val_loss improved from 8.44797 to 8.13743, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.002.h5
# Epoch 3/96
# 360/360 [==============================] - 134s 374ms/step - loss: 7.5933 - gender_output_loss: 0.5437 - image_quality_output_loss: 0.9071 - age_output_loss: 1.4142 - weight_output_loss: 0.9723 - bag_output_loss: 0.8789 - footwear_output_loss: 0.8787 - pose_output_loss: 0.9215 - emotion_output_loss: 0.8962 - gender_output_acc: 0.7247 - image_quality_output_acc: 0.5631 - age_output_acc: 0.3987 - weight_output_acc: 0.6395 - bag_output_acc: 0.5882 - footwear_output_acc: 0.6011 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7115 - val_loss: 7.7589 - val_gender_output_loss: 0.6276 - val_image_quality_output_loss: 0.9325 - val_age_output_loss: 1.4000 - val_weight_output_loss: 1.0138 - val_bag_output_loss: 0.8960 - val_footwear_output_loss: 0.9022 - val_pose_output_loss: 0.9126 - val_emotion_output_loss: 0.8938 - val_gender_output_acc: 0.6880 - val_image_quality_output_acc: 0.5441 - val_age_output_acc: 0.3983 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5784 - val_footwear_output_acc: 0.5823 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00003: val_loss improved from 8.13743 to 7.75890, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.003.h5
# Epoch 4/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.6058 - gender_output_loss: 0.5452 - image_quality_output_loss: 0.9110 - age_output_loss: 1.4139 - weight_output_loss: 0.9733 - bag_output_loss: 0.8818 - footwear_output_loss: 0.8822 - pose_output_loss: 0.9215 - emotion_output_loss: 0.8971 - gender_output_acc: 0.7220 - image_quality_output_acc: 0.5635 - age_output_acc: 0.3984 - weight_output_acc: 0.6398 - bag_output_acc: 0.5857 - footwear_output_acc: 0.6029 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7115 - val_loss: 7.8515 - val_gender_output_loss: 0.6016 - val_image_quality_output_loss: 0.9145 - val_age_output_loss: 1.4055 - val_weight_output_loss: 1.0130 - val_bag_output_loss: 0.8960 - val_footwear_output_loss: 1.0143 - val_pose_output_loss: 0.9306 - val_emotion_output_loss: 0.8969 - val_gender_output_acc: 0.6791 - val_image_quality_output_acc: 0.5476 - val_age_output_acc: 0.3978 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5739 - val_footwear_output_acc: 0.4578 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00004: val_loss did not improve from 7.75890
# Epoch 5/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.6079 - gender_output_loss: 0.5503 - image_quality_output_loss: 0.9096 - age_output_loss: 1.4141 - weight_output_loss: 0.9717 - bag_output_loss: 0.8818 - footwear_output_loss: 0.8824 - pose_output_loss: 0.9217 - emotion_output_loss: 0.8975 - gender_output_acc: 0.7205 - image_quality_output_acc: 0.5605 - age_output_acc: 0.3977 - weight_output_acc: 0.6394 - bag_output_acc: 0.5897 - footwear_output_acc: 0.6076 - pose_output_acc: 0.6167 - emotion_output_acc: 0.7113 - val_loss: 7.8330 - val_gender_output_loss: 0.7301 - val_image_quality_output_loss: 0.9118 - val_age_output_loss: 1.3959 - val_weight_output_loss: 1.0167 - val_bag_output_loss: 0.9216 - val_footwear_output_loss: 0.8664 - val_pose_output_loss: 0.9137 - val_emotion_output_loss: 0.8991 - val_gender_output_acc: 0.6741 - val_image_quality_output_acc: 0.5565 - val_age_output_acc: 0.3894 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5759 - val_footwear_output_acc: 0.6161 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00005: val_loss did not improve from 7.75890
# Epoch 6/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.6221 - gender_output_loss: 0.5589 - image_quality_output_loss: 0.9120 - age_output_loss: 1.4157 - weight_output_loss: 0.9736 - bag_output_loss: 0.8849 - footwear_output_loss: 0.8809 - pose_output_loss: 0.9222 - emotion_output_loss: 0.8965 - gender_output_acc: 0.7097 - image_quality_output_acc: 0.5608 - age_output_acc: 0.3963 - weight_output_acc: 0.6399 - bag_output_acc: 0.5802 - footwear_output_acc: 0.6022 - pose_output_acc: 0.6170 - emotion_output_acc: 0.7114Epoch 6/96
#
# 360/360 [==============================] - 136s 379ms/step - loss: 7.6220 - gender_output_loss: 0.5586 - image_quality_output_loss: 0.9116 - age_output_loss: 1.4158 - weight_output_loss: 0.9739 - bag_output_loss: 0.8849 - footwear_output_loss: 0.8812 - pose_output_loss: 0.9224 - emotion_output_loss: 0.8961 - gender_output_acc: 0.7098 - image_quality_output_acc: 0.5612 - age_output_acc: 0.3963 - weight_output_acc: 0.6398 - bag_output_acc: 0.5804 - footwear_output_acc: 0.6021 - pose_output_acc: 0.6169 - emotion_output_acc: 0.7115 - val_loss: 8.5137 - val_gender_output_loss: 1.0895 - val_image_quality_output_loss: 0.9077 - val_age_output_loss: 1.4462 - val_weight_output_loss: 1.0238 - val_bag_output_loss: 1.0194 - val_footwear_output_loss: 1.0181 - val_pose_output_loss: 0.9272 - val_emotion_output_loss: 0.9049 - val_gender_output_acc: 0.5709 - val_image_quality_output_acc: 0.5570 - val_age_output_acc: 0.3968 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5729 - val_footwear_output_acc: 0.5377 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00006: val_loss did not improve from 7.75890
# Epoch 7/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.6108 - gender_output_loss: 0.5509 - image_quality_output_loss: 0.9162 - age_output_loss: 1.4163 - weight_output_loss: 0.9753 - bag_output_loss: 0.8852 - footwear_output_loss: 0.8706 - pose_output_loss: 0.9214 - emotion_output_loss: 0.8989 - gender_output_acc: 0.7184 - image_quality_output_acc: 0.5615 - age_output_acc: 0.3969 - weight_output_acc: 0.6392 - bag_output_acc: 0.5876 - footwear_output_acc: 0.6069 - pose_output_acc: 0.6167 - emotion_output_acc: 0.7110
# Epoch 00006: val_loss did not improve from 7.75890
# Epoch 7/96
# 360/360 [==============================] - 136s 379ms/step - loss: 7.6104 - gender_output_loss: 0.5510 - image_quality_output_loss: 0.9164 - age_output_loss: 1.4166 - weight_output_loss: 0.9748 - bag_output_loss: 0.8857 - footwear_output_loss: 0.8706 - pose_output_loss: 0.9212 - emotion_output_loss: 0.8979 - gender_output_acc: 0.7182 - image_quality_output_acc: 0.5613 - age_output_acc: 0.3969 - weight_output_acc: 0.6396 - bag_output_acc: 0.5872 - footwear_output_acc: 0.6070 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7115 - val_loss: 9.0335 - val_gender_output_loss: 0.6530 - val_image_quality_output_loss: 1.0155 - val_age_output_loss: 1.4233 - val_weight_output_loss: 1.0210 - val_bag_output_loss: 0.9090 - val_footwear_output_loss: 1.9985 - val_pose_output_loss: 0.9218 - val_emotion_output_loss: 0.9161 - val_gender_output_acc: 0.5843 - val_image_quality_output_acc: 0.5417 - val_age_output_acc: 0.3239 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5719 - val_footwear_output_acc: 0.3705 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00007: val_loss did not improve from 7.75890
# Epoch 8/96
# 360/360 [==============================] - 136s 379ms/step - loss: 7.6199 - gender_output_loss: 0.5547 - image_quality_output_loss: 0.9169 - age_output_loss: 1.4160 - weight_output_loss: 0.9748 - bag_output_loss: 0.8843 - footwear_output_loss: 0.8801 - pose_output_loss: 0.9215 - emotion_output_loss: 0.8969 - gender_output_acc: 0.7168 - image_quality_output_acc: 0.5595 - age_output_acc: 0.3959 - weight_output_acc: 0.6399 - bag_output_acc: 0.5835 - footwear_output_acc: 0.6002 - pose_output_acc: 0.6166 - emotion_output_acc: 0.7115 - val_loss: 7.9587 - val_gender_output_loss: 0.6891 - val_image_quality_output_loss: 0.9024 - val_age_output_loss: 1.4387 - val_weight_output_loss: 1.0222 - val_bag_output_loss: 0.9359 - val_footwear_output_loss: 0.9867 - val_pose_output_loss: 0.9117 - val_emotion_output_loss: 0.8982 - val_gender_output_acc: 0.6076 - val_image_quality_output_acc: 0.5491 - val_age_output_acc: 0.3621 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5729 - val_footwear_output_acc: 0.5427 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00008: val_loss did not improve from 7.75890
# Epoch 9/96
# 360/360 [==============================] - 137s 380ms/step - loss: 7.5841 - gender_output_loss: 0.5442 - image_quality_output_loss: 0.9162 - age_output_loss: 1.4149 - weight_output_loss: 0.9744 - bag_output_loss: 0.8815 - footwear_output_loss: 0.8655 - pose_output_loss: 0.9184 - emotion_output_loss: 0.8961 - gender_output_acc: 0.7255 - image_quality_output_acc: 0.5597 - age_output_acc: 0.3999 - weight_output_acc: 0.6397 - bag_output_acc: 0.5899 - footwear_output_acc: 0.6089 - pose_output_acc: 0.6167 - emotion_output_acc: 0.7115 - val_loss: 8.0280 - val_gender_output_loss: 0.7515 - val_image_quality_output_loss: 0.9536 - val_age_output_loss: 1.4106 - val_weight_output_loss: 1.0241 - val_bag_output_loss: 0.9059 - val_footwear_output_loss: 0.9932 - val_pose_output_loss: 0.9145 - val_emotion_output_loss: 0.9027 - val_gender_output_acc: 0.5342 - val_image_quality_output_acc: 0.5471 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5392 - val_footwear_output_acc: 0.5218 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00009: val_loss did not improve from 7.75890
# Epoch 10/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.5384 - gender_output_loss: 0.5237 - image_quality_output_loss: 0.9126 - age_output_loss: 1.4115 - weight_output_loss: 0.9734 - bag_output_loss: 0.8808 - footwear_output_loss: 0.8524 - pose_output_loss: 0.9168 - emotion_output_loss: 0.8963 - gender_output_acc: 0.7397 - image_quality_output_acc: 0.5638 - age_output_acc: 0.3974 - weight_output_acc: 0.6395 - bag_output_acc: 0.5873 - footwear_output_acc: 0.6207 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7115 - val_loss: 7.9062 - val_gender_output_loss: 0.8281 - val_image_quality_output_loss: 0.9011 - val_age_output_loss: 1.4070 - val_weight_output_loss: 1.0291 - val_bag_output_loss: 0.8945 - val_footwear_output_loss: 0.8563 - val_pose_output_loss: 0.9125 - val_emotion_output_loss: 0.9078 - val_gender_output_acc: 0.5094 - val_image_quality_output_acc: 0.5501 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5714 - val_footwear_output_acc: 0.6071 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00010: val_loss did not improve from 7.75890
# Epoch 11/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.4982 - gender_output_loss: 0.5097 - image_quality_output_loss: 0.9089 - age_output_loss: 1.4114 - weight_output_loss: 0.9718 - bag_output_loss: 0.8753 - footwear_output_loss: 0.8425 - pose_output_loss: 0.9152 - emotion_output_loss: 0.8947 - gender_output_acc: 0.7459 - image_quality_output_acc: 0.5640 - age_output_acc: 0.3989 - weight_output_acc: 0.6390 - bag_output_acc: 0.5984 - footwear_output_acc: 0.6235 - pose_output_acc: 0.6166 - emotion_output_acc: 0.7114
# Epoch 00010: val_loss did not improve from 7.75890
# 360/360 [==============================] - 136s 378ms/step - loss: 7.4983 - gender_output_loss: 0.5100 - image_quality_output_loss: 0.9086 - age_output_loss: 1.4113 - weight_output_loss: 0.9722 - bag_output_loss: 0.8750 - footwear_output_loss: 0.8429 - pose_output_loss: 0.9151 - emotion_output_loss: 0.8946 - gender_output_acc: 0.7457 - image_quality_output_acc: 0.5643 - age_output_acc: 0.3988 - weight_output_acc: 0.6390 - bag_output_acc: 0.5984 - footwear_output_acc: 0.6233 - pose_output_acc: 0.6167 - emotion_output_acc: 0.7115 - val_loss: 8.7632 - val_gender_output_loss: 0.5845 - val_image_quality_output_loss: 0.9395 - val_age_output_loss: 1.4122 - val_weight_output_loss: 1.0310 - val_bag_output_loss: 0.8737 - val_footwear_output_loss: 1.9117 - val_pose_output_loss: 0.9359 - val_emotion_output_loss: 0.9071 - val_gender_output_acc: 0.7148 - val_image_quality_output_acc: 0.5347 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5903 - val_footwear_output_acc: 0.3735 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00011: val_loss did not improve from 7.75890
# Epoch 12/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.4983 - gender_output_loss: 0.5100 - image_quality_output_loss: 0.9086 - age_output_loss: 1.4113 - weight_output_loss: 0.9722 - bag_output_loss: 0.8750 - footwear_output_loss: 0.8429 - pose_output_loss: 0.9151 - emotion_output_loss: 0.8946 - gender_output_acc: 0.7457 - image_quality_output_acc: 0.5643 - age_output_acc: 0.3988 - weight_output_acc: 0.6390 - bag_output_acc: 0.5984 - footwear_output_acc: 0.6233 - pose_output_acc: 0.6167 - emotion_output_acc: 0.7115 - val_loss: 8.7632 - val_gender_output_loss: 0.5845 - val_image_quality_output_loss: 0.9395 - val_age_output_loss: 1.4122 - val_weight_output_loss: 1.0310 - val_bag_output_loss: 0.8737 - val_footwear_output_loss: 1.9117 - val_pose_output_loss: 0.9359 - val_emotion_output_loss: 0.9071 - val_gender_output_acc: 0.7148 - val_image_quality_output_acc: 0.5347 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5903 - val_footwear_output_acc: 0.3735 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
# 360/360 [==============================] - 136s 378ms/step - loss: 7.4606 - gender_output_loss: 0.4949 - image_quality_output_loss: 0.9081 - age_output_loss: 1.4071 - weight_output_loss: 0.9701 - bag_output_loss: 0.8748 - footwear_output_loss: 0.8338 - pose_output_loss: 0.9123 - emotion_output_loss: 0.8929 - gender_output_acc: 0.7615 - image_quality_output_acc: 0.5652 - age_output_acc: 0.3982 - weight_output_acc: 0.6398 - bag_output_acc: 0.5938 - footwear_output_acc: 0.6308 - pose_output_acc: 0.6166 - emotion_output_acc: 0.7116 - val_loss: 7.6616 - val_gender_output_loss: 0.5530 - val_image_quality_output_loss: 0.9224 - val_age_output_loss: 1.3951 - val_weight_output_loss: 1.0128 - val_bag_output_loss: 0.8817 - val_footwear_output_loss: 0.9420 - val_pose_output_loss: 0.8992 - val_emotion_output_loss: 0.8897 - val_gender_output_acc: 0.7376 - val_image_quality_output_acc: 0.5466 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5977 - val_footwear_output_acc: 0.5689 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00012: val_loss improved from 7.75890 to 7.66159, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.012.h5
# Epoch 13/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.4372 - gender_output_loss: 0.4896 - image_quality_output_loss: 0.9075 - age_output_loss: 1.4061 - weight_output_loss: 0.9706 - bag_output_loss: 0.8709 - footwear_output_loss: 0.8272 - pose_output_loss: 0.9090 - emotion_output_loss: 0.8913 - gender_output_acc: 0.7631 - image_quality_output_acc: 0.5620 - age_output_acc: 0.3975 - weight_output_acc: 0.6394 - bag_output_acc: 0.6033 - footwear_output_acc: 0.6314 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7118
# 360/360 [==============================] - 136s 378ms/step - loss: 7.4378 - gender_output_loss: 0.4896 - image_quality_output_loss: 0.9073 - age_output_loss: 1.4066 - weight_output_loss: 0.9704 - bag_output_loss: 0.8707 - footwear_output_loss: 0.8272 - pose_output_loss: 0.9090 - emotion_output_loss: 0.8921 - gender_output_acc: 0.7633 - image_quality_output_acc: 0.5619 - age_output_acc: 0.3970 - weight_output_acc: 0.6396 - bag_output_acc: 0.6034 - footwear_output_acc: 0.6313 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7114 - val_loss: 7.7673 - val_gender_output_loss: 0.6922 - val_image_quality_output_loss: 0.8850 - val_age_output_loss: 1.4282 - val_weight_output_loss: 1.0668 - val_bag_output_loss: 0.8885 - val_footwear_output_loss: 0.8325 - val_pose_output_loss: 0.8994 - val_emotion_output_loss: 0.9107 - val_gender_output_acc: 0.6240 - val_image_quality_output_acc: 0.5689 - val_age_output_acc: 0.3993 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.6404 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00013: val_loss did not improve from 7.66159
# Epoch 14/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3943 - gender_output_loss: 0.4705 - image_quality_output_loss: 0.9004 - age_output_loss: 1.4066 - weight_output_loss: 0.9685 - bag_output_loss: 0.8672 - footwear_output_loss: 0.8193 - pose_output_loss: 0.9074 - emotion_output_loss: 0.8911 - gender_output_acc: 0.7774 - image_quality_output_acc: 0.5683 - age_output_acc: 0.3988 - weight_output_acc: 0.6395 - bag_output_acc: 0.6026 - footwear_output_acc: 0.6345 - pose_output_acc: 0.6166 - emotion_output_acc: 0.7115 - val_loss: 7.4963 - val_gender_output_loss: 0.5434 - val_image_quality_output_loss: 0.8939 - val_age_output_loss: 1.3970 - val_weight_output_loss: 1.0112 - val_bag_output_loss: 0.8821 - val_footwear_output_loss: 0.8235 - val_pose_output_loss: 0.8927 - val_emotion_output_loss: 0.8899 - val_gender_output_acc: 0.7381 - val_image_quality_output_acc: 0.5461 - val_age_output_acc: 0.3869 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5933 - val_footwear_output_acc: 0.6424 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00014: val_loss improved from 7.66159 to 7.49632, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.014.h5
# Epoch 15/96
# 360/360 [==============================] - 136s 377ms/step - loss: 7.3572 - gender_output_loss: 0.4586 - image_quality_output_loss: 0.8972 - age_output_loss: 1.4056 - weight_output_loss: 0.9689 - bag_output_loss: 0.8628 - footwear_output_loss: 0.8081 - pose_output_loss: 0.9036 - emotion_output_loss: 0.8902 - gender_output_acc: 0.7861 - image_quality_output_acc: 0.5753 - age_output_acc: 0.3976 - weight_output_acc: 0.6396 - bag_output_acc: 0.6085 - footwear_output_acc: 0.6411 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7115 - val_loss: 7.2966 - val_gender_output_loss: 0.4340 - val_image_quality_output_loss: 0.8905 - val_age_output_loss: 1.3909 - val_weight_output_loss: 1.0208 - val_bag_output_loss: 0.8539 - val_footwear_output_loss: 0.7779 - val_pose_output_loss: 0.8775 - val_emotion_output_loss: 0.8895 - val_gender_output_acc: 0.8110 - val_image_quality_output_acc: 0.5625 - val_age_output_acc: 0.3968 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6086 - val_footwear_output_acc: 0.6493 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00015: val_loss improved from 7.49632 to 7.29658, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.015.h5
# Epoch 16/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3045 - gender_output_loss: 0.4396 - image_quality_output_loss: 0.8907 - age_output_loss: 1.4019 - weight_output_loss: 0.9662 - bag_output_loss: 0.8598 - footwear_output_loss: 0.7951 - pose_output_loss: 0.9015 - emotion_output_loss: 0.8882 - gender_output_acc: 0.7981 - image_quality_output_acc: 0.5703 - age_output_acc: 0.4002 - weight_output_acc: 0.6398 - bag_output_acc: 0.6122 - footwear_output_acc: 0.6508 - pose_output_acc: 0.6169 - emotion_output_acc: 0.7115 - val_loss: 7.2516 - val_gender_output_loss: 0.4274 - val_image_quality_output_loss: 0.8721 - val_age_output_loss: 1.3919 - val_weight_output_loss: 1.0140 - val_bag_output_loss: 0.8472 - val_footwear_output_loss: 0.7685 - val_pose_output_loss: 0.8795 - val_emotion_output_loss: 0.8897 - val_gender_output_acc: 0.8080 - val_image_quality_output_acc: 0.5650 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6230 - val_footwear_output_acc: 0.6592 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00016: val_loss improved from 7.29658 to 7.25161, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.016.h5
# Epoch 17/96
# 360/360 [==============================] - 136s 377ms/step - loss: 7.2927 - gender_output_loss: 0.4326 - image_quality_output_loss: 0.8902 - age_output_loss: 1.4017 - weight_output_loss: 0.9669 - bag_output_loss: 0.8579 - footwear_output_loss: 0.7945 - pose_output_loss: 0.9007 - emotion_output_loss: 0.8871 - gender_output_acc: 0.8063 - image_quality_output_acc: 0.5760 - age_output_acc: 0.3979 - weight_output_acc: 0.6398 - bag_output_acc: 0.6134 - footwear_output_acc: 0.6521 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7118 - val_loss: 7.3381 - val_gender_output_loss: 0.4367 - val_image_quality_output_loss: 0.9104 - val_age_output_loss: 1.3910 - val_weight_output_loss: 1.0170 - val_bag_output_loss: 0.8516 - val_footwear_output_loss: 0.7977 - val_pose_output_loss: 0.8814 - val_emotion_output_loss: 0.8914 - val_gender_output_acc: 0.8026 - val_image_quality_output_acc: 0.5605 - val_age_output_acc: 0.3919 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6066 - val_footwear_output_acc: 0.6374 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00017: val_loss did not improve from 7.25161
# Epoch 18/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.3280 - gender_output_loss: 0.4499 - image_quality_output_loss: 0.8973 - age_output_loss: 1.4027 - weight_output_loss: 0.9685 - bag_output_loss: 0.8631 - footwear_output_loss: 0.7985 - pose_output_loss: 0.8990 - emotion_output_loss: 0.8885 - gender_output_acc: 0.7877 - image_quality_output_acc: 0.5719 - age_output_acc: 0.4002 - weight_output_acc: 0.6394 - bag_output_acc: 0.6077 - footwear_output_acc: 0.6488 - pose_output_acc: 0.6170 - emotion_output_acc: 0.7115Epoch 18/96
#
# Epoch 00017: val_loss did not improve from 7.25161
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3277 - gender_output_loss: 0.4498 - image_quality_output_loss: 0.8970 - age_output_loss: 1.4030 - weight_output_loss: 0.9682 - bag_output_loss: 0.8632 - footwear_output_loss: 0.7981 - pose_output_loss: 0.8991 - emotion_output_loss: 0.8888 - gender_output_acc: 0.7878 - image_quality_output_acc: 0.5722 - age_output_acc: 0.3998 - weight_output_acc: 0.6396 - bag_output_acc: 0.6077 - footwear_output_acc: 0.6489 - pose_output_acc: 0.6169 - emotion_output_acc: 0.7114 - val_loss: 7.4147 - val_gender_output_loss: 0.5322 - val_image_quality_output_loss: 0.8992 - val_age_output_loss: 1.3927 - val_weight_output_loss: 1.0137 - val_bag_output_loss: 0.8686 - val_footwear_output_loss: 0.7676 - val_pose_output_loss: 0.8879 - val_emotion_output_loss: 0.8928 - val_gender_output_acc: 0.7287 - val_image_quality_output_acc: 0.5526 - val_age_output_acc: 0.3988 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5952 - val_footwear_output_acc: 0.6662 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00018: val_loss did not improve from 7.25161
# Epoch 19/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3473 - gender_output_loss: 0.4582 - image_quality_output_loss: 0.8989 - age_output_loss: 1.4036 - weight_output_loss: 0.9695 - bag_output_loss: 0.8623 - footwear_output_loss: 0.8099 - pose_output_loss: 0.8967 - emotion_output_loss: 0.8885 - gender_output_acc: 0.7869 - image_quality_output_acc: 0.5648 - age_output_acc: 0.3990 - weight_output_acc: 0.6397 - bag_output_acc: 0.6050 - footwear_output_acc: 0.6418 - pose_output_acc: 0.6168 - emotion_output_acc: 0.7115 - val_loss: 8.7202 - val_gender_output_loss: 1.3525 - val_image_quality_output_loss: 0.9279 - val_age_output_loss: 1.4574 - val_weight_output_loss: 1.0375 - val_bag_output_loss: 1.0806 - val_footwear_output_loss: 0.8453 - val_pose_output_loss: 0.9503 - val_emotion_output_loss: 0.9096 - val_gender_output_acc: 0.5749 - val_image_quality_output_acc: 0.5501 - val_age_output_acc: 0.3785 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5739 - val_footwear_output_acc: 0.6394 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00019: val_loss did not improve from 7.25161
# Epoch 20/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3796 - gender_output_loss: 0.4664 - image_quality_output_loss: 0.9066 - age_output_loss: 1.4073 - weight_output_loss: 0.9702 - bag_output_loss: 0.8650 - footwear_output_loss: 0.8203 - pose_output_loss: 0.8949 - emotion_output_loss: 0.8903 - gender_output_acc: 0.7814 - image_quality_output_acc: 0.5648 - age_output_acc: 0.3993 - weight_output_acc: 0.6398 - bag_output_acc: 0.6088 - footwear_output_acc: 0.6310 - pose_output_acc: 0.6169 - emotion_output_acc: 0.7116 - val_loss: 7.6981 - val_gender_output_loss: 0.6195 - val_image_quality_output_loss: 0.9629 - val_age_output_loss: 1.4085 - val_weight_output_loss: 1.0366 - val_bag_output_loss: 0.8846 - val_footwear_output_loss: 0.8313 - val_pose_output_loss: 0.8961 - val_emotion_output_loss: 0.9004 - val_gender_output_acc: 0.6766 - val_image_quality_output_acc: 0.5432 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5685 - val_footwear_output_acc: 0.6394 - val_pose_output_acc: 0.6230 - val_emotion_output_acc: 0.7133
#
# Epoch 00020: val_loss did not improve from 7.25161
# Epoch 21/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3898 - gender_output_loss: 0.4809 - image_quality_output_loss: 0.9063 - age_output_loss: 1.4079 - weight_output_loss: 0.9711 - bag_output_loss: 0.8694 - footwear_output_loss: 0.8219 - pose_output_loss: 0.8831 - emotion_output_loss: 0.8916 - gender_output_acc: 0.7698 - image_quality_output_acc: 0.5650 - age_output_acc: 0.3978 - weight_output_acc: 0.6398 - bag_output_acc: 0.6002 - footwear_output_acc: 0.6362 - pose_output_acc: 0.6172 - emotion_output_acc: 0.7116 - val_loss: 7.7795 - val_gender_output_loss: 0.5299 - val_image_quality_output_loss: 1.0505 - val_age_output_loss: 1.4023 - val_weight_output_loss: 1.0203 - val_bag_output_loss: 0.8855 - val_footwear_output_loss: 0.9025 - val_pose_output_loss: 0.9335 - val_emotion_output_loss: 0.8975 - val_gender_output_acc: 0.7763 - val_image_quality_output_acc: 0.5357 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5804 - val_footwear_output_acc: 0.5942 - val_pose_output_acc: 0.5938 - val_emotion_output_acc: 0.7133
#
# Epoch 00020: val_loss did not improve from 7.25161
#
# Epoch 00021: val_loss did not improve from 7.25161
# Epoch 21/96
# Epoch 22/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3852 - gender_output_loss: 0.4906 - image_quality_output_loss: 0.9085 - age_output_loss: 1.4119 - weight_output_loss: 0.9699 - bag_output_loss: 0.8768 - footwear_output_loss: 0.8296 - pose_output_loss: 0.8512 - emotion_output_loss: 0.8896 - gender_output_acc: 0.7591 - image_quality_output_acc: 0.5676 - age_output_acc: 0.3980 - weight_output_acc: 0.6403 - bag_output_acc: 0.5957 - footwear_output_acc: 0.6267 - pose_output_acc: 0.6240 - emotion_output_acc: 0.7115 - val_loss: 7.6328 - val_gender_output_loss: 0.5831 - val_image_quality_output_loss: 0.9368 - val_age_output_loss: 1.3982 - val_weight_output_loss: 1.0167 - val_bag_output_loss: 0.8551 - val_footwear_output_loss: 0.9271 - val_pose_output_loss: 0.8690 - val_emotion_output_loss: 0.8896 - val_gender_output_acc: 0.7540 - val_image_quality_output_acc: 0.5506 - val_age_output_acc: 0.3943 - val_weight_output_acc: 0.6106 - val_bag_output_acc: 0.6225 - val_footwear_output_acc: 0.5650 - val_pose_output_acc: 0.6255 - val_emotion_output_acc: 0.7133
#
# Epoch 00022: val_loss did not improve from 7.25161
# Epoch 23/96
# 360/360 [==============================] - 136s 377ms/step - loss: 7.3867 - gender_output_loss: 0.5008 - image_quality_output_loss: 0.9201 - age_output_loss: 1.4127 - weight_output_loss: 0.9737 - bag_output_loss: 0.8748 - footwear_output_loss: 0.8342 - pose_output_loss: 0.8250 - emotion_output_loss: 0.8879 - gender_output_acc: 0.7559 - image_quality_output_acc: 0.5648 - age_output_acc: 0.3977 - weight_output_acc: 0.6395 - bag_output_acc: 0.5974 - footwear_output_acc: 0.6288 - pose_output_acc: 0.6332 - emotion_output_acc: 0.7115 - val_loss: 7.9506 - val_gender_output_loss: 0.7568 - val_image_quality_output_loss: 0.9391 - val_age_output_loss: 1.4020 - val_weight_output_loss: 1.0253 - val_bag_output_loss: 0.9085 - val_footwear_output_loss: 1.0258 - val_pose_output_loss: 0.8356 - val_emotion_output_loss: 0.8997 - val_gender_output_acc: 0.5288 - val_image_quality_output_acc: 0.5511 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5412 - val_footwear_output_acc: 0.4866 - val_pose_output_acc: 0.6295 - val_emotion_output_acc: 0.7133
#
# Epoch 00023: val_loss did not improve from 7.25161
# Epoch 24/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.3830 - gender_output_loss: 0.5033 - image_quality_output_loss: 0.9248 - age_output_loss: 1.4125 - weight_output_loss: 0.9739 - bag_output_loss: 0.8771 - footwear_output_loss: 0.8471 - pose_output_loss: 0.8000 - emotion_output_loss: 0.8861 - gender_output_acc: 0.7520 - image_quality_output_acc: 0.5635 - age_output_acc: 0.3972 - weight_output_acc: 0.6394 - bag_output_acc: 0.5931 - footwear_output_acc: 0.6179 - pose_output_acc: 0.6496 - emotion_output_acc: 0.7114
#
# Epoch 00023: val_loss did not improve from 7.25161
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3825 - gender_output_loss: 0.5034 - image_quality_output_loss: 0.9246 - age_output_loss: 1.4125 - weight_output_loss: 0.9737 - bag_output_loss: 0.8772 - footwear_output_loss: 0.8470 - pose_output_loss: 0.8000 - emotion_output_loss: 0.8860 - gender_output_acc: 0.7521 - image_quality_output_acc: 0.5636 - age_output_acc: 0.3972 - weight_output_acc: 0.6393 - bag_output_acc: 0.5930 - footwear_output_acc: 0.6181 - pose_output_acc: 0.6497 - emotion_output_acc: 0.7114 - val_loss: 7.8399 - val_gender_output_loss: 0.7090 - val_image_quality_output_loss: 0.9647 - val_age_output_loss: 1.4045 - val_weight_output_loss: 1.0765 - val_bag_output_loss: 0.8903 - val_footwear_output_loss: 0.8884 - val_pose_output_loss: 0.8332 - val_emotion_output_loss: 0.9144 - val_gender_output_acc: 0.5531 - val_image_quality_output_acc: 0.5332 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5813 - val_footwear_output_acc: 0.6121 - val_pose_output_acc: 0.6285 - val_emotion_output_acc: 0.7133
#
# Epoch 00024: val_loss did not improve from 7.25161
# Epoch 25/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.3416 - gender_output_loss: 0.4980 - image_quality_output_loss: 0.9189 - age_output_loss: 1.4132 - weight_output_loss: 0.9741 - bag_output_loss: 0.8771 - footwear_output_loss: 0.8423 - pose_output_loss: 0.7744 - emotion_output_loss: 0.8843 - gender_output_acc: 0.7602 - image_quality_output_acc: 0.5621 - age_output_acc: 0.3968 - weight_output_acc: 0.6396 - bag_output_acc: 0.5997 - footwear_output_acc: 0.6229 - pose_output_acc: 0.6567 - emotion_output_acc: 0.7113
# Epoch 00024: val_loss did not improve from 7.25161
# 360/360 [==============================] - 136s 378ms/step - loss: 7.3429 - gender_output_loss: 0.4984 - image_quality_output_loss: 0.9187 - age_output_loss: 1.4130 - weight_output_loss: 0.9751 - bag_output_loss: 0.8770 - footwear_output_loss: 0.8422 - pose_output_loss: 0.7752 - emotion_output_loss: 0.8840 - gender_output_acc: 0.7601 - image_quality_output_acc: 0.5624 - age_output_acc: 0.3969 - weight_output_acc: 0.6391 - bag_output_acc: 0.5999 - footwear_output_acc: 0.6230 - pose_output_acc: 0.6562 - emotion_output_acc: 0.7114 - val_loss: 7.8738 - val_gender_output_loss: 0.6681 - val_image_quality_output_loss: 0.9391 - val_age_output_loss: 1.3998 - val_weight_output_loss: 1.0170 - val_bag_output_loss: 0.8876 - val_footwear_output_loss: 0.8324 - val_pose_output_loss: 1.0634 - val_emotion_output_loss: 0.9068 - val_gender_output_acc: 0.6518 - val_image_quality_output_acc: 0.5501 - val_age_output_acc: 0.3988 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5779 - val_footwear_output_acc: 0.6429 - val_pose_output_acc: 0.3948 - val_emotion_output_acc: 0.7133
#
# Epoch 00025: val_loss did not improve from 7.25161
# Epoch 26/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.3054 - gender_output_loss: 0.4945 - image_quality_output_loss: 0.9158 - age_output_loss: 1.4117 - weight_output_loss: 0.9732 - bag_output_loss: 0.8797 - footwear_output_loss: 0.8301 - pose_output_loss: 0.7601 - emotion_output_loss: 0.8807 - gender_output_acc: 0.7530 - image_quality_output_acc: 0.5694 - age_output_acc: 0.3966 - weight_output_acc: 0.6394 - bag_output_acc: 0.5964 - footwear_output_acc: 0.6280 - pose_output_acc: 0.6625 - emotion_output_acc: 0.7120
# Epoch 00025: val_loss did not improve from 7.25161
# 360/360 [==============================] - 137s 380ms/step - loss: 7.3052 - gender_output_loss: 0.4944 - image_quality_output_loss: 0.9164 - age_output_loss: 1.4115 - weight_output_loss: 0.9730 - bag_output_loss: 0.8793 - footwear_output_loss: 0.8298 - pose_output_loss: 0.7598 - emotion_output_loss: 0.8814 - gender_output_acc: 0.7532 - image_quality_output_acc: 0.5690 - age_output_acc: 0.3967 - weight_output_acc: 0.6397 - bag_output_acc: 0.5969 - footwear_output_acc: 0.6281 - pose_output_acc: 0.6625 - emotion_output_acc: 0.7116 - val_loss: 7.3198 - val_gender_output_loss: 0.4933 - val_image_quality_output_loss: 0.9133 - val_age_output_loss: 1.3967 - val_weight_output_loss: 1.0286 - val_bag_output_loss: 0.8749 - val_footwear_output_loss: 0.7969 - val_pose_output_loss: 0.7727 - val_emotion_output_loss: 0.8841 - val_gender_output_acc: 0.7703 - val_image_quality_output_acc: 0.5541 - val_age_output_acc: 0.4008 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5888 - val_footwear_output_acc: 0.6414 - val_pose_output_acc: 0.6429 - val_emotion_output_acc: 0.7133
#
# Epoch 00026: val_loss did not improve from 7.25161
# Epoch 27/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.2342 - gender_output_loss: 0.4718 - image_quality_output_loss: 0.9167 - age_output_loss: 1.4076 - weight_output_loss: 0.9722 - bag_output_loss: 0.8719 - footwear_output_loss: 0.8250 - pose_output_loss: 0.7330 - emotion_output_loss: 0.8768 - gender_output_acc: 0.7729 - image_quality_output_acc: 0.5656 - age_output_acc: 0.3957 - weight_output_acc: 0.6393 - bag_output_acc: 0.6005 - footwear_output_acc: 0.6295 - pose_output_acc: 0.6825 - emotion_output_acc: 0.7116 - val_loss: 7.6008 - val_gender_output_loss: 0.4889 - val_image_quality_output_loss: 0.9444 - val_age_output_loss: 1.3914 - val_weight_output_loss: 1.0177 - val_bag_output_loss: 0.8587 - val_footwear_output_loss: 1.1035 - val_pose_output_loss: 0.7472 - val_emotion_output_loss: 0.8901 - val_gender_output_acc: 0.7604 - val_image_quality_output_acc: 0.5203 - val_age_output_acc: 0.3988 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6062 - val_footwear_output_acc: 0.5208 - val_pose_output_acc: 0.6815 - val_emotion_output_acc: 0.7133
#
# Epoch 00027: val_loss did not improve from 7.25161
# Epoch 28/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.1862 - gender_output_loss: 0.4587 - image_quality_output_loss: 0.9113 - age_output_loss: 1.4076 - weight_output_loss: 0.9716 - bag_output_loss: 0.8699 - footwear_output_loss: 0.8157 - pose_output_loss: 0.7163 - emotion_output_loss: 0.8766 - gender_output_acc: 0.7833 - image_quality_output_acc: 0.5644 - age_output_acc: 0.3963 - weight_output_acc: 0.6394 - bag_output_acc: 0.5998 - footwear_output_acc: 0.6380 - pose_output_acc: 0.6923 - emotion_output_acc: 0.7114
# Epoch 00027: val_loss did not improve from 7.25161
# 360/360 [==============================] - 136s 379ms/step - loss: 7.1860 - gender_output_loss: 0.4585 - image_quality_output_loss: 0.9114 - age_output_loss: 1.4076 - weight_output_loss: 0.9716 - bag_output_loss: 0.8699 - footwear_output_loss: 0.8158 - pose_output_loss: 0.7161 - emotion_output_loss: 0.8766 - gender_output_acc: 0.7833 - image_quality_output_acc: 0.5641 - age_output_acc: 0.3964 - weight_output_acc: 0.6394 - bag_output_acc: 0.5999 - footwear_output_acc: 0.6379 - pose_output_acc: 0.6922 - emotion_output_acc: 0.7114 - val_loss: 7.7452 - val_gender_output_loss: 0.8296 - val_image_quality_output_loss: 0.9245 - val_age_output_loss: 1.4248 - val_weight_output_loss: 1.0170 - val_bag_output_loss: 0.9310 - val_footwear_output_loss: 0.8300 - val_pose_output_loss: 0.7458 - val_emotion_output_loss: 0.8843 - val_gender_output_acc: 0.6314 - val_image_quality_output_acc: 0.5486 - val_age_output_acc: 0.3760 - val_weight_output_acc: 0.6106 - val_bag_output_acc: 0.5769 - val_footwear_output_acc: 0.6468 - val_pose_output_acc: 0.6558 - val_emotion_output_acc: 0.7133
#
# Epoch 00028: val_loss did not improve from 7.25161
# Epoch 29/96
# 360/360 [==============================] - 136s 379ms/step - loss: 7.1860 - gender_output_loss: 0.4585 - image_quality_output_loss: 0.9114 - age_output_loss: 1.4076 - weight_output_loss: 0.9716 - bag_output_loss: 0.8699 - footwear_output_loss: 0.8158 - pose_output_loss: 0.7161 - emotion_output_loss: 0.8766 - gender_output_acc: 0.7833 - image_quality_output_acc: 0.5641 - age_output_acc: 0.3964 - weight_output_acc: 0.6394 - bag_output_acc: 0.5999 - footwear_output_acc: 0.6379 - pose_output_acc: 0.6922 - emotion_output_acc: 0.7114 - val_loss: 7.7452 - val_gender_output_loss: 0.8296 - val_image_quality_output_loss: 0.9245 - val_age_output_loss: 1.4248 - val_weight_output_loss: 1.0170 - val_bag_output_loss: 0.9310 - val_footwear_output_loss: 0.8300 - val_pose_output_loss: 0.7458 - val_emotion_output_loss: 0.8843 - val_gender_output_acc: 0.6314 - val_image_quality_output_acc: 0.5486 - val_age_output_acc: 0.3760 - val_weight_output_acc: 0.6106 - val_bag_output_acc: 0.5769 - val_footwear_output_acc: 0.6468 - val_pose_output_acc: 0.6558 - val_emotion_output_acc: 0.7133
# 360/360 [==============================] - 136s 378ms/step - loss: 7.1402 - gender_output_loss: 0.4426 - image_quality_output_loss: 0.9081 - age_output_loss: 1.4047 - weight_output_loss: 0.9708 - bag_output_loss: 0.8723 - footwear_output_loss: 0.8059 - pose_output_loss: 0.7028 - emotion_output_loss: 0.8756 - gender_output_acc: 0.7933 - image_quality_output_acc: 0.5654 - age_output_acc: 0.3994 - weight_output_acc: 0.6400 - bag_output_acc: 0.6013 - footwear_output_acc: 0.6396 - pose_output_acc: 0.6974 - emotion_output_acc: 0.7115 - val_loss: 7.1408 - val_gender_output_loss: 0.4318 - val_image_quality_output_loss: 0.9018 - val_age_output_loss: 1.3879 - val_weight_output_loss: 1.0159 - val_bag_output_loss: 0.8594 - val_footwear_output_loss: 0.8412 - val_pose_output_loss: 0.6683 - val_emotion_output_loss: 0.8775 - val_gender_output_acc: 0.7966 - val_image_quality_output_acc: 0.5605 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6022 - val_footwear_output_acc: 0.6260 - val_pose_output_acc: 0.6974 - val_emotion_output_acc: 0.7133
#
# Epoch 00029: val_loss improved from 7.25161 to 7.14082, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.029.h5
# Epoch 30/96
# 360/360 [==============================] - 136s 377ms/step - loss: 7.0874 - gender_output_loss: 0.4281 - image_quality_output_loss: 0.9070 - age_output_loss: 1.4033 - weight_output_loss: 0.9683 - bag_output_loss: 0.8662 - footwear_output_loss: 0.8016 - pose_output_loss: 0.6871 - emotion_output_loss: 0.8693 - gender_output_acc: 0.8009 - image_quality_output_acc: 0.5668 - age_output_acc: 0.3995 - weight_output_acc: 0.6397 - bag_output_acc: 0.6058 - footwear_output_acc: 0.6443 - pose_output_acc: 0.7049 - emotion_output_acc: 0.7115 - val_loss: 7.1474 - val_gender_output_loss: 0.4710 - val_image_quality_output_loss: 0.8892 - val_age_output_loss: 1.3902 - val_weight_output_loss: 1.0167 - val_bag_output_loss: 0.8657 - val_footwear_output_loss: 0.7676 - val_pose_output_loss: 0.7112 - val_emotion_output_loss: 0.8796 - val_gender_output_acc: 0.7753 - val_image_quality_output_acc: 0.5610 - val_age_output_acc: 0.4003 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6091 - val_footwear_output_acc: 0.6662 - val_pose_output_acc: 0.6870 - val_emotion_output_acc: 0.7133
#
# Epoch 00030: val_loss did not improve from 7.14082
# Epoch 31/96
# 359/360 [============================>.] - ETA: 0s - loss: 7.0350 - gender_output_loss: 0.4164 - image_quality_output_loss: 0.9053 - age_output_loss: 1.4006 - weight_output_loss: 0.9666 - bag_output_loss: 0.8617 - footwear_output_loss: 0.7889 - pose_output_loss: 0.6713 - emotion_output_loss: 0.8683 - gender_output_acc: 0.8069 - image_quality_output_acc: 0.5706 - age_output_acc: 0.3991 - weight_output_acc: 0.6416 - bag_output_acc: 0.6111 - footwear_output_acc: 0.6524 - pose_output_acc: 0.7132 - emotion_output_acc: 0.7114Epoch 31/96
#
# Epoch 00030: val_loss did not improve from 7.14082
# 360/360 [==============================] - 136s 379ms/step - loss: 7.0346 - gender_output_loss: 0.4163 - image_quality_output_loss: 0.9056 - age_output_loss: 1.4003 - weight_output_loss: 0.9670 - bag_output_loss: 0.8614 - footwear_output_loss: 0.7888 - pose_output_loss: 0.6711 - emotion_output_loss: 0.8684 - gender_output_acc: 0.8069 - image_quality_output_acc: 0.5705 - age_output_acc: 0.3996 - weight_output_acc: 0.6412 - bag_output_acc: 0.6110 - footwear_output_acc: 0.6523 - pose_output_acc: 0.7133 - emotion_output_acc: 0.7115 - val_loss: 7.0642 - val_gender_output_loss: 0.4503 - val_image_quality_output_loss: 0.8915 - val_age_output_loss: 1.3905 - val_weight_output_loss: 1.0144 - val_bag_output_loss: 0.8610 - val_footwear_output_loss: 0.7706 - val_pose_output_loss: 0.6538 - val_emotion_output_loss: 0.8768 - val_gender_output_acc: 0.7897 - val_image_quality_output_acc: 0.5699 - val_age_output_acc: 0.3993 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6101 - val_footwear_output_acc: 0.6632 - val_pose_output_acc: 0.7098 - val_emotion_output_acc: 0.7133
#
# Epoch 00031: val_loss improved from 7.14082 to 7.06419, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.031.h5
# Epoch 32/96
# 360/360 [==============================] - 136s 378ms/step - loss: 6.9770 - gender_output_loss: 0.3952 - image_quality_output_loss: 0.8985 - age_output_loss: 1.4002 - weight_output_loss: 0.9684 - bag_output_loss: 0.8602 - footwear_output_loss: 0.7802 - pose_output_loss: 0.6521 - emotion_output_loss: 0.8672 - gender_output_acc: 0.8207 - image_quality_output_acc: 0.5702 - age_output_acc: 0.4012 - weight_output_acc: 0.6397 - bag_output_acc: 0.6107 - footwear_output_acc: 0.6570 - pose_output_acc: 0.7246 - emotion_output_acc: 0.7114 - val_loss: 6.9142 - val_gender_output_loss: 0.3836 - val_image_quality_output_loss: 0.8881 - val_age_output_loss: 1.3843 - val_weight_output_loss: 1.0123 - val_bag_output_loss: 0.8494 - val_footwear_output_loss: 0.7428 - val_pose_output_loss: 0.6313 - val_emotion_output_loss: 0.8676 - val_gender_output_acc: 0.8333 - val_image_quality_output_acc: 0.5650 - val_age_output_acc: 0.3988 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6235 - val_footwear_output_acc: 0.6751 - val_pose_output_acc: 0.7307 - val_emotion_output_acc: 0.7133
#
# Epoch 00032: val_loss improved from 7.06419 to 6.91424, saving model to /content/gdrive/My Drive/models3/cifar10_%s_model.032.h5
# Epoch 33/96
# 360/360 [==============================] - 136s 377ms/step - loss: 6.9559 - gender_output_loss: 0.3837 - image_quality_output_loss: 0.8999 - age_output_loss: 1.3965 - weight_output_loss: 0.9672 - bag_output_loss: 0.8625 - footwear_output_loss: 0.7807 - pose_output_loss: 0.6455 - emotion_output_loss: 0.8651 - gender_output_acc: 0.8279 - image_quality_output_acc: 0.5701 - age_output_acc: 0.3999 - weight_output_acc: 0.6396 - bag_output_acc: 0.6089 - footwear_output_acc: 0.6556 - pose_output_acc: 0.7263 - emotion_output_acc: 0.7115 - val_loss: 7.1381 - val_gender_output_loss: 0.4823 - val_image_quality_output_loss: 0.9188 - val_age_output_loss: 1.3910 - val_weight_output_loss: 1.0122 - val_bag_output_loss: 0.8651 - val_footwear_output_loss: 0.7679 - val_pose_output_loss: 0.6738 - val_emotion_output_loss: 0.8724 - val_gender_output_acc: 0.7664 - val_image_quality_output_acc: 0.5580 - val_age_output_acc: 0.3889 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5962 - val_footwear_output_acc: 0.6691 - val_pose_output_acc: 0.7168 - val_emotion_output_acc: 0.7133
#
# Epoch 00033: val_loss did not improve from 6.91424
# Epoch 34/96
# 360/360 [==============================] - 136s 378ms/step - loss: 7.0077 - gender_output_loss: 0.3982 - image_quality_output_loss: 0.9010 - age_output_loss: 1.3999 - weight_output_loss: 0.9673 - bag_output_loss: 0.8616 - footwear_output_loss: 0.7882 - pose_output_loss: 0.6694 - emotion_output_loss: 0.8677 - gender_output_acc: 0.8170 - image_quality_output_acc: 0.5701 - age_output_acc: 0.4003 - weight_output_acc: 0.6399 - bag_output_acc: 0.6125 - footwear_output_acc: 0.6563 - pose_output_acc: 0.7162 - emotion_output_acc: 0.7114 - val_loss: 7.0469 - val_gender_output_loss: 0.4611 - val_image_quality_output_loss: 0.8813 - val_age_output_loss: 1.3957 - val_weight_output_loss: 1.0165 - val_bag_output_loss: 0.8545 - val_footwear_output_loss: 0.7652 - val_pose_output_loss: 0.6459 - val_emotion_output_loss: 0.8728 - val_gender_output_acc: 0.7827 - val_image_quality_output_acc: 0.5670 - val_age_output_acc: 0.4018 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6146 - val_footwear_output_acc: 0.6746 - val_pose_output_acc: 0.7178 - val_emotion_output_acc: 0.7133
# Epoch 34/96
#
# ...
#
# Epoch 00086: val_loss did not improve from 6.68381
# Epoch 87/96
# 359/360 [============================>.] - ETA: 0s - loss: 6.8553 - gender_output_loss: 0.3610 - image_quality_output_loss: 0.9007 - age_output_loss: 1.3977 - weight_output_loss: 0.9670 - bag_output_loss: 0.8614 - footwear_output_loss: 0.7751 - pose_output_loss: 0.5505 - emotion_output_loss: 0.8584 - gender_output_acc: 0.8411 - image_quality_output_acc: 0.5720 - age_output_acc: 0.3979 - weight_output_acc: 0.6394 - bag_output_acc: 0.6132 - footwear_output_acc: 0.6623 - pose_output_acc: 0.7869 - emotion_output_acc: 0.7119Epoch 87/96
# Epoch 00086: val_loss did not improve from 6.68381
# 360/360 [==============================] - 137s 380ms/step - loss: 6.8556 - gender_output_loss: 0.3609 - image_quality_output_loss: 0.9010 - age_output_loss: 1.3975 - weight_output_loss: 0.9672 - bag_output_loss: 0.8611 - footwear_output_loss: 0.7751 - pose_output_loss: 0.5503 - emotion_output_loss: 0.8589 - gender_output_acc: 0.8411 - image_quality_output_acc: 0.5718 - age_output_acc: 0.3982 - weight_output_acc: 0.6392 - bag_output_acc: 0.6131 - footwear_output_acc: 0.6623 - pose_output_acc: 0.7871 - emotion_output_acc: 0.7116 - val_loss: 7.1368 - val_gender_output_loss: 0.4277 - val_image_quality_output_loss: 0.9102 - val_age_output_loss: 1.3951 - val_weight_output_loss: 1.0277 - val_bag_output_loss: 0.8731 - val_footwear_output_loss: 0.7746 - val_pose_output_loss: 0.6607 - val_emotion_output_loss: 0.8823 - val_gender_output_acc: 0.7961 - val_image_quality_output_acc: 0.5446 - val_age_output_acc: 0.4013 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5853 - val_footwear_output_acc: 0.6706 - val_pose_output_acc: 0.7168 - val_emotion_output_acc: 0.7133
#
# Epoch 00087: val_loss did not improve from 6.68381
# Epoch 88/96
# 359/360 [============================>.] - ETA: 0s - loss: 6.8886 - gender_output_loss: 0.3699 - image_quality_output_loss: 0.9034 - age_output_loss: 1.3990 - weight_output_loss: 0.9676 - bag_output_loss: 0.8620 - footwear_output_loss: 0.7841 - pose_output_loss: 0.5516 - emotion_output_loss: 0.8634 - gender_output_acc: 0.8394 - image_quality_output_acc: 0.5649 - age_output_acc: 0.3958 - weight_output_acc: 0.6391 - bag_output_acc: 0.6132 - footwear_output_acc: 0.6589 - pose_output_acc: 0.7839 - emotion_output_acc: 0.7114Epoch 88/96
# 360/360 [==============================] - 137s 380ms/step - loss: 6.8556 - gender_output_loss: 0.3609 - image_quality_output_loss: 0.9010 - age_output_loss: 1.3975 - weight_output_loss: 0.9672 - bag_output_loss: 0.8611 - footwear_output_loss: 0.7751 - pose_output_loss: 0.5503 - emotion_output_loss: 0.8589 - gender_output_acc: 0.8411 - image_quality_output_acc: 0.5718 - age_output_acc: 0.3982 - weight_output_acc: 0.6392 - bag_output_acc: 0.6131 - footwear_output_acc: 0.6623 - pose_output_acc: 0.7871 - emotion_output_acc: 0.7116 - val_loss: 7.1368 - val_gender_output_loss: 0.4277 - val_image_quality_output_loss: 0.9102 - val_age_output_loss: 1.3951 - val_weight_output_loss: 1.0277 - val_bag_output_loss: 0.8731 - val_footwear_output_loss: 0.7746 - val_pose_output_loss: 0.6607 - val_emotion_output_loss: 0.8823 - val_gender_output_acc: 0.7961 - val_image_quality_output_acc: 0.5446 - val_age_output_acc: 0.4013 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5853 - val_footwear_output_acc: 0.6706 - val_pose_output_acc: 0.7168 - val_emotion_output_acc: 0.7133
#
# 360/360 [==============================] - 137s 380ms/step - loss: 6.8894 - gender_output_loss: 0.3700 - image_quality_output_loss: 0.9040 - age_output_loss: 1.3987 - weight_output_loss: 0.9676 - bag_output_loss: 0.8616 - footwear_output_loss: 0.7843 - pose_output_loss: 0.5527 - emotion_output_loss: 0.8630 - gender_output_acc: 0.8393 - image_quality_output_acc: 0.5646 - age_output_acc: 0.3962 - weight_output_acc: 0.6391 - bag_output_acc: 0.6133 - footwear_output_acc: 0.6589 - pose_output_acc: 0.7834 - emotion_output_acc: 0.7116 - val_loss: 7.3159 - val_gender_output_loss: 0.4810 - val_image_quality_output_loss: 1.0282 - val_age_output_loss: 1.4014 - val_weight_output_loss: 1.0184 - val_bag_output_loss: 0.8582 - val_footwear_output_loss: 0.8012 - val_pose_output_loss: 0.6529 - val_emotion_output_loss: 0.8844 - val_gender_output_acc: 0.7892 - val_image_quality_output_acc: 0.5451 - val_age_output_acc: 0.3998 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6052 - val_footwear_output_acc: 0.6567 - val_pose_output_acc: 0.7381 - val_emotion_output_acc: 0.7133
#
# Epoch 00088: val_loss did not improve from 6.68381
# Epoch 89/96
# 360/360 [==============================] - 137s 380ms/step - loss: 6.8894 - gender_output_loss: 0.3700 - image_quality_output_loss: 0.9040 - age_output_loss: 1.3987 - weight_output_loss: 0.9676 - bag_output_loss: 0.8616 - footwear_output_loss: 0.7843 - pose_output_loss: 0.5527 - emotion_output_loss: 0.8630 - gender_output_acc: 0.8393 - image_quality_output_acc: 0.5646 - age_output_acc: 0.3962 - weight_output_acc: 0.6391 - bag_output_acc: 0.6133 - footwear_output_acc: 0.6589 - pose_output_acc: 0.7834 - emotion_output_acc: 0.7116 - val_loss: 7.3159 - val_gender_output_loss: 0.4810 - val_image_quality_output_loss: 1.0282 - val_age_output_loss: 1.4014 - val_weight_output_loss: 1.0184 - val_bag_output_loss: 0.8582 - val_footwear_output_loss: 0.8012 - val_pose_output_loss: 0.6529 - val_emotion_output_loss: 0.8844 - val_gender_output_acc: 0.7892 - val_image_quality_output_acc: 0.5451 - val_age_output_acc: 0.3998 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6052 - val_footwear_output_acc: 0.6567 - val_pose_output_acc: 0.7381 - val_emotion_output_acc: 0.7133
# 360/360 [==============================] - 137s 380ms/step - loss: 6.9089 - gender_output_loss: 0.3810 - image_quality_output_loss: 0.9013 - age_output_loss: 1.3970 - weight_output_loss: 0.9698 - bag_output_loss: 0.8631 - footwear_output_loss: 0.7836 - pose_output_loss: 0.5595 - emotion_output_loss: 0.8611 - gender_output_acc: 0.8280 - image_quality_output_acc: 0.5700 - age_output_acc: 0.4023 - weight_output_acc: 0.6391 - bag_output_acc: 0.6128 - footwear_output_acc: 0.6616 - pose_output_acc: 0.7789 - emotion_output_acc: 0.7115 - val_loss: 7.0794 - val_gender_output_loss: 0.4220 - val_image_quality_output_loss: 0.9129 - val_age_output_loss: 1.3988 - val_weight_output_loss: 1.0186 - val_bag_output_loss: 0.8625 - val_footwear_output_loss: 0.8278 - val_pose_output_loss: 0.5707 - val_emotion_output_loss: 0.8717 - val_gender_output_acc: 0.8130 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3988 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6012 - val_footwear_output_acc: 0.6290 - val_pose_output_acc: 0.7614 - val_emotion_output_acc: 0.7133
#
# Epoch 00089: val_loss did not improve from 6.68381
# Epoch 90/96
# 360/360 [==============================] - 137s 380ms/step - loss: 6.8502 - gender_output_loss: 0.3603 - image_quality_output_loss: 0.9004 - age_output_loss: 1.3977 - weight_output_loss: 0.9665 - bag_output_loss: 0.8604 - footwear_output_loss: 0.7702 - pose_output_loss: 0.5374 - emotion_output_loss: 0.8623 - gender_output_acc: 0.8402 - image_quality_output_acc: 0.5647 - age_output_acc: 0.4011 - weight_output_acc: 0.6398 - bag_output_acc: 0.6120 - footwear_output_acc: 0.6660 - pose_output_acc: 0.7898 - emotion_output_acc: 0.7116 - val_loss: 7.0186 - val_gender_output_loss: 0.3912 - val_image_quality_output_loss: 0.9016 - val_age_output_loss: 1.3796 - val_weight_output_loss: 1.0167 - val_bag_output_loss: 0.8703 - val_footwear_output_loss: 0.8013 - val_pose_output_loss: 0.5855 - val_emotion_output_loss: 0.8766 - val_gender_output_acc: 0.8289 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.4058 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5813 - val_footwear_output_acc: 0.6548 - val_pose_output_acc: 0.7515 - val_emotion_output_acc: 0.7133
#
# Epoch 00090: val_loss did not improve from 6.68381
#
# Epoch 00089: val_loss did not improve from 6.68381
# Epoch 91/96
# 359/360 [============================>.] - ETA: 0s - loss: 6.8095 - gender_output_loss: 0.3499 - image_quality_output_loss: 0.9002 - age_output_loss: 1.3939 - weight_output_loss: 0.9672 - bag_output_loss: 0.8573 - footwear_output_loss: 0.7669 - pose_output_loss: 0.5181 - emotion_output_loss: 0.8599 - gender_output_acc: 0.8441 - image_quality_output_acc: 0.5698 - age_output_acc: 0.3986 - weight_output_acc: 0.6411 - bag_output_acc: 0.6151 - footwear_output_acc: 0.6697 - pose_output_acc: 0.7931 - emotion_output_acc: 0.7114Epoch 91/96
#
# 360/360 [==============================] - 137s 381ms/step - loss: 6.8094 - gender_output_loss: 0.3504 - image_quality_output_loss: 0.8998 - age_output_loss: 1.3944 - weight_output_loss: 0.9672 - bag_output_loss: 0.8574 - footwear_output_loss: 0.7667 - pose_output_loss: 0.5179 - emotion_output_loss: 0.8595 - gender_output_acc: 0.8437 - image_quality_output_acc: 0.5700 - age_output_acc: 0.3986 - weight_output_acc: 0.6411 - bag_output_acc: 0.6150 - footwear_output_acc: 0.6696 - pose_output_acc: 0.7934 - emotion_output_acc: 0.7115 - val_loss: 7.2362 - val_gender_output_loss: 0.5506 - val_image_quality_output_loss: 0.9421 - val_age_output_loss: 1.3955 - val_weight_output_loss: 1.0266 - val_bag_output_loss: 0.8929 - val_footwear_output_loss: 0.7729 - val_pose_output_loss: 0.5736 - val_emotion_output_loss: 0.8856 - val_gender_output_acc: 0.7232 - val_image_quality_output_acc: 0.5451 - val_age_output_acc: 0.3998 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.6726 - val_pose_output_acc: 0.7614 - val_emotion_output_acc: 0.7133
#
# Epoch 00091: val_loss did not improve from 6.68381
# Epoch 92/96
# 360/360 [==============================] - 137s 381ms/step - loss: 6.7522 - gender_output_loss: 0.3258 - image_quality_output_loss: 0.8896 - age_output_loss: 1.3966 - weight_output_loss: 0.9664 - bag_output_loss: 0.8528 - footwear_output_loss: 0.7599 - pose_output_loss: 0.5091 - emotion_output_loss: 0.8556 - gender_output_acc: 0.8591 - image_quality_output_acc: 0.5711 - age_output_acc: 0.4036 - weight_output_acc: 0.6407 - bag_output_acc: 0.6170 - footwear_output_acc: 0.6696 - pose_output_acc: 0.8028 - emotion_output_acc: 0.7115 - val_loss: 6.9094 - val_gender_output_loss: 0.3555 - val_image_quality_output_loss: 0.9082 - val_age_output_loss: 1.3886 - val_weight_output_loss: 1.0147 - val_bag_output_loss: 0.8501 - val_footwear_output_loss: 0.7628 - val_pose_output_loss: 0.5646 - val_emotion_output_loss: 0.8688 - val_gender_output_acc: 0.8462 - val_image_quality_output_acc: 0.5670 - val_age_output_acc: 0.3929 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6195 - val_footwear_output_acc: 0.6642 - val_pose_output_acc: 0.7669 - val_emotion_output_acc: 0.7133
#
# Epoch 00092: val_loss did not improve from 6.68381
# Epoch 93/96
# 360/360 [==============================] - 137s 381ms/step - loss: 6.7040 - gender_output_loss: 0.3113 - image_quality_output_loss: 0.8961 - age_output_loss: 1.3909 - weight_output_loss: 0.9657 - bag_output_loss: 0.8485 - footwear_output_loss: 0.7490 - pose_output_loss: 0.4888 - emotion_output_loss: 0.8579 - gender_output_acc: 0.8659 - image_quality_output_acc: 0.5730 - age_output_acc: 0.4036 - weight_output_acc: 0.6389 - bag_output_acc: 0.6224 - footwear_output_acc: 0.6754 - pose_output_acc: 0.8125 - emotion_output_acc: 0.7115 - val_loss: 6.8902 - val_gender_output_loss: 0.3887 - val_image_quality_output_loss: 0.8834 - val_age_output_loss: 1.3814 - val_weight_output_loss: 1.0103 - val_bag_output_loss: 0.8719 - val_footwear_output_loss: 0.7423 - val_pose_output_loss: 0.5439 - val_emotion_output_loss: 0.8730 - val_gender_output_acc: 0.8269 - val_image_quality_output_acc: 0.5575 - val_age_output_acc: 0.3948 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.5962 - val_footwear_output_acc: 0.6830 - val_pose_output_acc: 0.7812 - val_emotion_output_acc: 0.7133
#
# Epoch 00093: val_loss did not improve from 6.68381
# Epoch 94/96
# 360/360 [==============================] - 137s 380ms/step - loss: 6.6447 - gender_output_loss: 0.2937 - image_quality_output_loss: 0.8872 - age_output_loss: 1.3915 - weight_output_loss: 0.9635 - bag_output_loss: 0.8499 - footwear_output_loss: 0.7410 - pose_output_loss: 0.4686 - emotion_output_loss: 0.8540 - gender_output_acc: 0.8727 - image_quality_output_acc: 0.5678 - age_output_acc: 0.4028 - weight_output_acc: 0.6403 - bag_output_acc: 0.6210 - footwear_output_acc: 0.6796 - pose_output_acc: 0.8232 - emotion_output_acc: 0.7115 - val_loss: 6.8914 - val_gender_output_loss: 0.4133 - val_image_quality_output_loss: 0.9007 - val_age_output_loss: 1.3794 - val_weight_output_loss: 1.0112 - val_bag_output_loss: 0.8568 - val_footwear_output_loss: 0.7682 - val_pose_output_loss: 0.5023 - val_emotion_output_loss: 0.8649 - val_gender_output_acc: 0.8199 - val_image_quality_output_acc: 0.5570 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6096 - val_footwear_output_acc: 0.6726 - val_pose_output_acc: 0.7956 - val_emotion_output_acc: 0.7133
#
# Epoch 00094: val_loss did not improve from 6.68381
# Epoch 95/96
#
# Epoch 00093: val_loss did not improve from 6.68381
# 360/360 [==============================] - 137s 382ms/step - loss: 6.5742 - gender_output_loss: 0.2711 - image_quality_output_loss: 0.8824 - age_output_loss: 1.3896 - weight_output_loss: 0.9621 - bag_output_loss: 0.8448 - footwear_output_loss: 0.7274 - pose_output_loss: 0.4507 - emotion_output_loss: 0.8518 - gender_output_acc: 0.8878 - image_quality_output_acc: 0.5765 - age_output_acc: 0.4023 - weight_output_acc: 0.6411 - bag_output_acc: 0.6245 - footwear_output_acc: 0.6866 - pose_output_acc: 0.8322 - emotion_output_acc: 0.7114 - val_loss: 6.7577 - val_gender_output_loss: 0.3371 - val_image_quality_output_loss: 0.8793 - val_age_output_loss: 1.3787 - val_weight_output_loss: 1.0116 - val_bag_output_loss: 0.8408 - val_footwear_output_loss: 0.7432 - val_pose_output_loss: 0.5091 - val_emotion_output_loss: 0.8643 - val_gender_output_acc: 0.8591 - val_image_quality_output_acc: 0.5655 - val_age_output_acc: 0.3904 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6190 - val_footwear_output_acc: 0.6776 - val_pose_output_acc: 0.7887 - val_emotion_output_acc: 0.7133
#
# Epoch 00095: val_loss did not improve from 6.68381
# Epoch 96/96
# 360/360 [==============================] - 137s 381ms/step - loss: 6.5103 - gender_output_loss: 0.2507 - image_quality_output_loss: 0.8767 - age_output_loss: 1.3859 - weight_output_loss: 0.9622 - bag_output_loss: 0.8446 - footwear_output_loss: 0.7182 - pose_output_loss: 0.4275 - emotion_output_loss: 0.8511 - gender_output_acc: 0.8956 - image_quality_output_acc: 0.5778 - age_output_acc: 0.4016 - weight_output_acc: 0.6394 - bag_output_acc: 0.6262 - footwear_output_acc: 0.6891 - pose_output_acc: 0.8421 - emotion_output_acc: 0.7113 - val_loss: 6.6867 - val_gender_output_loss: 0.3065 - val_image_quality_output_loss: 0.8767 - val_age_output_loss: 1.3751 - val_weight_output_loss: 1.0112 - val_bag_output_loss: 0.8372 - val_footwear_output_loss: 0.7317 - val_pose_output_loss: 0.4965 - val_emotion_output_loss: 0.8585 - val_gender_output_acc: 0.8765 - val_image_quality_output_acc: 0.5704 - val_age_output_acc: 0.3973 - val_weight_output_acc: 0.6111 - val_bag_output_acc: 0.6131 - val_footwear_output_acc: 0.6850 - val_pose_output_acc: 0.7976 - val_emotion_output_acc: 0.7133
#
# Epoch 00096: val_loss did not improve from 6.68381

# %%
from keras.utils import plot_model
plot_model(model)
#, to_file='model.png'

# %%
def evaluate_model(model):
    results = model.evaluate_generator(valid_gen, verbose=1)
    accuracies = {}
    losses = {}
    for k, v in zip(model.metrics_names, results):
        if k.endswith('acc'):
            accuracies[k] = round(v * 100, 4) 
        else:
            losses[k] = v
    return accuracies
print(evaluate_model(model))
# Out:
# 63/63 [==============================] - 7s 116ms/step
# {'gender_output_acc': 87.6488, 'image_quality_output_acc': 57.0437, 'age_output_acc': 39.7321, 'weight_output_acc': 61.1111, 'bag_output_acc': 61.3095, 'footwear_output_acc': 68.502, 'pose_output_acc': 79.7619, 'emotion_output_acc': 71.3294}
